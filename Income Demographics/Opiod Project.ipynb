# %%
# Dependencies and Setup
from census import Census
from config import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from us import states
import matplotlib.pyplot as plt

# Census API Key
c = Census(census_key, year=2017)
gmaps.configure(api_key=gkey)

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data = c.acs5.get(("NAME","B01003_001E", "B19013_001E","B19301_001E","B17001_002E","B23025_005E",), {
                         'for': 'county:*'})

# %%
# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"NAME": "County Name","B01003_001E": "Population",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "county": "County","state":"State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Add in Employment Rate (Employment Count / Population)
census_pd["Unemployment Rate"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame

census_pd['FIPS Code'] = census_pd['State'].astype(str) + census_pd['County'].astype(str)
census_pd = census_pd[["FIPS Code","County", "State","County Name","Population","Household Income","Per Capita Income","Poverty Count","Poverty Rate","Unemployment Count", "Unemployment Rate"]]
census_pd.head()
# Out:
#   FIPS Code County State                           County Name  Population  \
# 0     72047    047    72        Corozal Municipio, Puerto Rico     34933.0
# 1     72095    095    72        Maunabo Municipio, Puerto Rico     11297.0
# 2     72111    111    72       Peñuelas Municipio, Puerto Rico     21661.0
# 3     72113    113    72          Ponce Municipio, Puerto Rico    148863.0
# 4     72131    131    72  San Sebastián Municipio, Puerto Rico     38970.0
#
#    Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0           14752.0             7887.0        19146.0     54.807775
# 1           17636.0             8830.0         5945.0     52.624591
# 2           16868.0             7983.0        12379.0     57.148793
# 3           16561.0            10775.0        75187.0     50.507514
# 4           14275.0             8072.0        21472.0     55.098794
#
#    Unemployment Count  Unemployment Rate
# 0              3296.0           9.435205
# 1               735.0           6.506152
# 2              1601.0           7.391164
# 3              7013.0           4.711043
# 4              3307.0           8.486015

# %%
len(census_pd)
# Out:
# 3220

# %%
# File to Load
CDC_Data = "CDC_Data.csv"

# Read Purchasing File and store into Pandas data frame
CDC_Table = pd.read_csv("CDC_Data.csv", encoding="ISO-8859-1",converters={'STCOUNTYFP': '{:0>5}'.format})
CDC_Table['STCOUNTYFP'] = CDC_Table.astype({"STCOUNTYFP": str})
CDC_Table = CDC_Table.rename(columns={"STCOUNTYFP": "FIPS Code"})



CDC_Table['Deaths'] = CDC_Table['Deaths'].replace(
                                            {'Missing': '0'
                                            })

CDC_Table['Deaths'] = CDC_Table['Deaths'].astype(int)

# %%
new_merged_df = pd.merge(census_pd,CDC_Table,how='outer',on='FIPS Code')
new_merged_df = new_merged_df.dropna(how='any')


new_merged_df['Per 100K'] = 100000 * \
     new_merged_df['Deaths'].astype(int) / new_merged_df['Population_y'].astype(int)

new_merged_df.head()
# Out:
#     FIPS Code County_x State                County Name  Population_x  \
# 84      01073      073    01  Jefferson County, Alabama      659460.0
# 97      01117      117    01     Shelby County, Alabama      208721.0
# 98      01115      115    01  St. Clair County, Alabama       86937.0
# 100     01003      003    01    Baldwin County, Alabama      203360.0
# 101     01043      043    01    Cullman County, Alabama       81703.0
#
#      Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 84            49321.0            29456.0       113368.0     17.191035
# 97            74063.0            35330.0        17127.0      8.205691
# 98            53483.0            24686.0        11656.0     13.407410
# 100           52562.0            29364.0        23728.0     11.667978
# 101           40997.0            21857.0        13157.0     16.103448
#
#      Unemployment Count  Unemployment Rate              County_y  Deaths  \
# 84              25044.0           3.797653  Jefferson County, AL   167.0
# 97               4650.0           2.227854     Shelby County, AL    27.0
# 98               2354.0           2.707708  St. Clair County, AL    15.0
# 100              5215.0           2.564418    Baldwin County, AL    19.0
# 101              1962.0           2.401381    Cullman County, AL    12.0
#
#     Population_y  Crude Rate % of Total Deaths   Per 100K
# 84        659197        25.3             0.40%  25.333853
# 97        213605        12.6             0.10%  12.640154
# 98         88199  Unreliable             0.00%  17.006996
# 100       212628  Unreliable             0.00%   8.935794
# 101        82755  Unreliable             0.00%  14.500634

# %%
list(new_merged_df)
# Out:
# ['FIPS Code',
#  'County_x',
#  'State',
#  'County Name',
#  'Population_x',
#  'Household Income',
#  'Per Capita Income',
#  'Poverty Count',
#  'Poverty Rate',
#  'Unemployment Count',
#  'Unemployment Rate',
#  'County_y',
#  'Deaths',
#  'Population_y',
#  'Crude Rate',
#  '% of Total Deaths',
#  'Per 100K']

# %%
# Store 'Lat' and 'Lng' into  locations 
counties = new_merged_df['County Name'].astype(list)


lat = []
lng = []
counter = 0
print(f'Beginning Data Retrieval')
print(f'-----------------------------')
# Extract latitude and longitude
for county in counties:
    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?address={county}&key={gkey}')
    geo_data = requests.get(target_url).json()
    lat.append(geo_data["results"][0]["geometry"]["location"]["lat"])
    lng.append(geo_data["results"][0]["geometry"]["location"]["lng"])
    counter += 1
    print(f'Processing record {counter} | {county}')
print(f'-----------------------------')
print(f'Data Retrieval Complete')
print(f'-----------------------------')
  
list_of_counties = list(zip(lat, lng))
counties_df = pd.DataFrame(list_of_counties)


counties_df.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 | Jefferson County, Alabama
# Processing record 2 | Shelby County, Alabama
# Processing record 3 | St. Clair County, Alabama
# Processing record 4 | Baldwin County, Alabama
# Processing record 5 | Cullman County, Alabama
# Processing record 6 | Tuscaloosa County, Alabama
# Processing record 7 | Etowah County, Alabama
# Processing record 8 | DeKalb County, Alabama
# Processing record 9 | Mobile County, Alabama
# Processing record 10 | Madison County, Alabama
# Processing record 11 | Matanuska-Susitna Borough, Alaska
# Processing record 12 | Juneau City and Borough, Alaska
# Processing record 13 | Anchorage Municipality, Alaska
# Processing record 14 | Pima County, Arizona
# Processing record 15 | Maricopa County, Arizona
# Processing record 16 | Cochise County, Arizona
# Processing record 17 | Yavapai County, Arizona
# Processing record 18 | Pinal County, Arizona
# Processing record 19 | Pulaski County, Arkansas
# Processing record 20 | Saline County, Arkansas
# Processing record 21 | Benton County, Arkansas
# Processing record 22 | Garland County, Arkansas
# Processing record 23 | Merced County, California
# Processing record 24 | Lake County, California
# Processing record 25 | Contra Costa County, California
# Processing record 26 | Stanislaus County, California
# Processing record 27 | Santa Barbara County, California
# Processing record 28 | Sonoma County, California
# Processing record 29 | Alameda County, California
# Processing record 30 | Sacramento County, California
# Processing record 31 | San Diego County, California
# Processing record 32 | San Francisco County, California
# Processing record 33 | Humboldt County, California
# Processing record 34 | Mendocino County, California
# Processing record 35 | Santa Cruz County, California
# Processing record 36 | Los Angeles County, California
# Processing record 37 | Riverside County, California
# Processing record 38 | San Bernardino County, California
# Processing record 39 | Santa Clara County, California
# Processing record 40 | Marin County, California
# Processing record 41 | Placer County, California
# Processing record 42 | Shasta County, California
# Processing record 43 | Solano County, California
# Processing record 44 | Butte County, California
# Processing record 45 | San Luis Obispo County, California
# Processing record 46 | Fresno County, California
# Processing record 47 | Kern County, California
# Processing record 48 | Orange County, California
# Processing record 49 | Ventura County, California
# Processing record 50 | San Mateo County, California
# Processing record 51 | San Joaquin County, California
# Processing record 52 | Adams County, Colorado
# Processing record 53 | Larimer County, Colorado
# Processing record 54 | Boulder County, Colorado
# Processing record 55 | Pueblo County, Colorado
# Processing record 56 | Mesa County, Colorado
# Processing record 57 | El Paso County, Colorado
# Processing record 58 | Arapahoe County, Colorado
# Processing record 59 | Denver County, Colorado
# Processing record 60 | Jefferson County, Colorado
# Processing record 61 | Weld County, Colorado
# Processing record 62 | New Haven County, Connecticut
# Processing record 63 | Litchfield County, Connecticut
# Processing record 64 | Hartford County, Connecticut
# Processing record 65 | Windham County, Connecticut
# Processing record 66 | New London County, Connecticut
# Processing record 67 | Middlesex County, Connecticut
# Processing record 68 | Tolland County, Connecticut
# Processing record 69 | Fairfield County, Connecticut
# Processing record 70 | Santa Rosa County, Florida
# Processing record 71 | New Castle County, Delaware
# Processing record 72 | Sussex County, Delaware
# Processing record 73 | Kent County, Delaware
# Processing record 74 | Manatee County, Florida
# Processing record 75 | Citrus County, Florida
# Processing record 76 | Volusia County, Florida
# Processing record 77 | Leon County, Florida
# Processing record 78 | Broward County, Florida
# Processing record 79 | Monroe County, Florida
# Processing record 80 | Escambia County, Florida
# Processing record 81 | Hernando County, Florida
# Processing record 82 | Hillsborough County, Florida
# Processing record 83 | Okaloosa County, Florida
# Processing record 84 | Duval County, Florida
# Processing record 85 | Brevard County, Florida
# Processing record 86 | Clay County, Florida
# Processing record 87 | Lake County, Florida
# Processing record 88 | Nassau County, Florida
# Processing record 89 | Pinellas County, Florida
# Processing record 90 | Polk County, Florida
# Processing record 91 | St. Lucie County, Florida
# Processing record 92 | Palm Beach County, Florida
# Processing record 93 | St. Johns County, Florida
# Processing record 94 | Seminole County, Florida
# Processing record 95 | Miami-Dade County, Florida
# Processing record 96 | Bay County, Florida
# Processing record 97 | Flagler County, Florida
# Processing record 98 | Osceola County, Florida
# Processing record 99 | Lee County, Florida
# Processing record 100 | Marion County, Florida
# Processing record 101 | Collier County, Florida
# Processing record 102 | Orange County, Florida
# Processing record 103 | Alachua County, Florida
# Processing record 104 | District of Columbia, District of Columbia
# Processing record 105 | Pasco County, Florida
# Processing record 106 | Columbia County, Florida
# Processing record 107 | Martin County, Florida
# Processing record 108 | Sarasota County, Florida
# Processing record 109 | DeKalb County, Georgia
# Processing record 110 | Jackson County, Georgia
# Processing record 111 | Muscogee County, Georgia
# Processing record 112 | Whitfield County, Georgia
# Processing record 113 | Bibb County, Georgia
# Processing record 114 | Chatham County, Georgia
# Processing record 115 | Catoosa County, Georgia
# Processing record 116 | Columbia County, Georgia
# Processing record 117 | Forsyth County, Georgia
# Processing record 118 | Carroll County, Georgia
# Processing record 119 | Coweta County, Georgia
# Processing record 120 | Cobb County, Georgia
# Processing record 121 | Walton County, Georgia
# Processing record 122 | Cherokee County, Georgia
# Processing record 123 | Newton County, Georgia
# Processing record 124 | Clayton County, Georgia
# Processing record 125 | Fulton County, Georgia
# Processing record 126 | Hall County, Georgia
# Processing record 127 | Henry County, Georgia
# Processing record 128 | Paulding County, Georgia
# Processing record 129 | Richmond County, Georgia
# Processing record 130 | Gwinnett County, Georgia
# Processing record 131 | Bartow County, Georgia
# Processing record 132 | Douglas County, Georgia
# Processing record 133 | Honolulu County, Hawaii
# Processing record 134 | Maui County, Hawaii
# Processing record 135 | Ada County, Idaho
# Processing record 136 | Bannock County, Idaho
# Processing record 137 | Madison County, Illinois
# Processing record 138 | Kankakee County, Illinois
# Processing record 139 | DuPage County, Illinois
# Processing record 140 | Sangamon County, Illinois
# Processing record 141 | Cook County, Illinois
# Processing record 142 | Macon County, Illinois
# Processing record 143 | Franklin County, Illinois
# Processing record 144 | McHenry County, Illinois
# Processing record 145 | McLean County, Illinois
# Processing record 146 | Rock Island County, Illinois
# Processing record 147 | St. Clair County, Illinois
# Processing record 148 | Champaign County, Illinois
# Processing record 149 | Kane County, Illinois
# Processing record 150 | Kendall County, Illinois
# Processing record 151 | Peoria County, Illinois
# Processing record 152 | Winnebago County, Illinois
# Processing record 153 | Boone County, Illinois
# Processing record 154 | Jersey County, Illinois
# Processing record 155 | DeKalb County, Illinois
# Processing record 156 | Vermilion County, Illinois
# Processing record 157 | Will County, Illinois
# Processing record 158 | Williamson County, Illinois
# Processing record 159 | Lake County, Illinois
# Processing record 160 | Tazewell County, Illinois
# Processing record 161 | Monroe County, Indiana
# Processing record 162 | Elkhart County, Indiana
# Processing record 163 | Starke County, Indiana
# Processing record 164 | Marion County, Indiana
# Processing record 165 | Wayne County, Indiana
# Processing record 166 | LaSalle County, Illinois
# Processing record 167 | Hendricks County, Indiana
# Processing record 168 | Jackson County, Indiana
# Processing record 169 | Howard County, Indiana
# Processing record 170 | Randolph County, Indiana
# Processing record 171 | Madison County, Indiana
# Processing record 172 | Floyd County, Indiana
# Processing record 173 | Allen County, Indiana
# Processing record 174 | Delaware County, Indiana
# Processing record 175 | Morgan County, Indiana
# Processing record 176 | St. Joseph County, Indiana
# Processing record 177 | Kosciusko County, Indiana
# Processing record 178 | Vanderburgh County, Indiana
# Processing record 179 | LaPorte County, Indiana
# Processing record 180 | Wabash County, Indiana
# Processing record 181 | Jay County, Indiana
# Processing record 182 | Porter County, Indiana
# Processing record 183 | Tippecanoe County, Indiana
# Processing record 184 | Hamilton County, Indiana
# Processing record 185 | Bartholomew County, Indiana
# Processing record 186 | Lake County, Indiana
# Processing record 187 | Montgomery County, Indiana
# Processing record 188 | Clark County, Indiana
# Processing record 189 | Fayette County, Indiana
# Processing record 190 | Linn County, Iowa
# Processing record 191 | Scott County, Iowa
# Processing record 192 | Polk County, Iowa
# Processing record 193 | Shawnee County, Kansas
# Processing record 194 | Sedgwick County, Kansas
# Processing record 195 | Johnson County, Kansas
# Processing record 196 | Douglas County, Kansas
# Processing record 197 | Nelson County, Kentucky
# Processing record 198 | Boone County, Kentucky
# Processing record 199 | Jessamine County, Kentucky
# Processing record 200 | Knox County, Kentucky
# Processing record 201 | Pike County, Kentucky
# Processing record 202 | Anderson County, Kentucky
# Processing record 203 | Floyd County, Kentucky
# Processing record 204 | Franklin County, Kentucky
# Processing record 205 | Kenton County, Kentucky
# Processing record 206 | Madison County, Kentucky
# Processing record 207 | Clark County, Kentucky
# Processing record 208 | Greenup County, Kentucky
# Processing record 209 | Campbell County, Kentucky
# Processing record 210 | Carter County, Kentucky
# Processing record 211 | Grant County, Kentucky
# Processing record 212 | Jefferson County, Kentucky
# Processing record 213 | Mason County, Kentucky
# Processing record 214 | Hardin County, Kentucky
# Processing record 215 | Montgomery County, Kentucky
# Processing record 216 | Scott County, Kentucky
# Processing record 217 | Warren County, Kentucky
# Processing record 218 | Boyd County, Kentucky
# Processing record 219 | Bullitt County, Kentucky
# Processing record 220 | Fayette County, Kentucky
# Processing record 221 | Pulaski County, Kentucky
# Processing record 222 | Penobscot County, Maine
# Processing record 223 | Androscoggin County, Maine
# Processing record 224 | Washington County, Maine
# Processing record 225 | Cumberland County, Maine
# Processing record 226 | York County, Maine
# Processing record 227 | Kennebec County, Maine
# Processing record 228 | Somerset County, Maine
# Processing record 229 | Jefferson Parish, Louisiana
# Processing record 230 | Rapides Parish, Louisiana
# Processing record 231 | Washington Parish, Louisiana
# Processing record 232 | St. Tammany Parish, Louisiana
# Processing record 233 | Caddo Parish, Louisiana
# Processing record 234 | Lafayette Parish, Louisiana
# Processing record 235 | Livingston Parish, Louisiana
# Processing record 236 | Orleans Parish, Louisiana
# Processing record 237 | East Baton Rouge Parish, Louisiana
# Processing record 238 | Suffolk County, Massachusetts
# Processing record 239 | Barnstable County, Massachusetts
# Processing record 240 | Middlesex County, Massachusetts
# Processing record 241 | Berkshire County, Massachusetts
# Processing record 242 | Bristol County, Massachusetts
# Processing record 243 | Hampden County, Massachusetts
# Processing record 244 | Plymouth County, Massachusetts
# Processing record 245 | Essex County, Massachusetts
# Processing record 246 | Franklin County, Massachusetts
# Processing record 247 | Norfolk County, Massachusetts
# Processing record 248 | Worcester County, Massachusetts
# Processing record 249 | Hampshire County, Massachusetts
# Processing record 250 | Worcester County, Maryland
# Processing record 251 | Baltimore city, Maryland
# Processing record 252 | Harford County, Maryland
# Processing record 253 | Allegany County, Maryland
# Processing record 254 | Howard County, Maryland
# Processing record 255 | Prince George's County, Maryland
# Processing record 256 | Anne Arundel County, Maryland
# Processing record 257 | Baltimore County, Maryland
# Processing record 258 | Frederick County, Maryland
# Processing record 259 | Calvert County, Maryland
# Processing record 260 | Montgomery County, Maryland
# Processing record 261 | Carroll County, Maryland
# Processing record 262 | St. Mary's County, Maryland
# Processing record 263 | Charles County, Maryland
# Processing record 264 | Dorchester County, Maryland
# Processing record 265 | Washington County, Maryland
# Processing record 266 | Wicomico County, Maryland
# Processing record 267 | Cecil County, Maryland
# Processing record 268 | Caroline County, Maryland
# Processing record 269 | Berrien County, Michigan
# Processing record 270 | Ingham County, Michigan
# Processing record 271 | Lenawee County, Michigan
# Processing record 272 | Montcalm County, Michigan
# Processing record 273 | St. Clair County, Michigan
# Processing record 274 | Van Buren County, Michigan
# Processing record 275 | Washtenaw County, Michigan
# Processing record 276 | Wayne County, Michigan
# Processing record 277 | Grand Traverse County, Michigan
# Processing record 278 | Genesee County, Michigan
# Processing record 279 | Livingston County, Michigan
# Processing record 280 | Kalamazoo County, Michigan
# Processing record 281 | Calhoun County, Michigan
# Processing record 282 | Kent County, Michigan
# Processing record 283 | Macomb County, Michigan
# Processing record 284 | Saginaw County, Michigan
# Processing record 285 | Shiawassee County, Michigan
# Processing record 286 | Eaton County, Michigan
# Processing record 287 | Monroe County, Michigan
# Processing record 288 | Oakland County, Michigan
# Processing record 289 | Muskegon County, Michigan
# Processing record 290 | Lapeer County, Michigan
# Processing record 291 | Ottawa County, Michigan
# Processing record 292 | Ionia County, Michigan
# Processing record 293 | Hennepin County, Minnesota
# Processing record 294 | Olmsted County, Minnesota
# Processing record 295 | St. Louis County, Minnesota
# Processing record 296 | Anoka County, Minnesota
# Processing record 297 | Dakota County, Minnesota
# Processing record 298 | Washington County, Minnesota
# Processing record 299 | Ramsey County, Minnesota
# Processing record 300 | Jackson County, Mississippi
# Processing record 301 | Harrison County, Mississippi
# Processing record 302 | DeSoto County, Mississippi
# Processing record 303 | Pearl River County, Mississippi
# Processing record 304 | Rankin County, Mississippi
# Processing record 305 | Hinds County, Mississippi
# Processing record 306 | Phelps County, Missouri
# Processing record 307 | St. Louis city, Missouri
# Processing record 308 | Greene County, Missouri
# Processing record 309 | Jefferson County, Missouri
# Processing record 310 | St. Louis County, Missouri
# Processing record 311 | Boone County, Missouri
# Processing record 312 | Franklin County, Missouri
# Processing record 313 | Jackson County, Missouri
# Processing record 314 | Lincoln County, Missouri
# Processing record 315 | St. Charles County, Missouri
# Processing record 316 | Clay County, Missouri
# Processing record 317 | Lancaster County, Nebraska
# Processing record 318 | Douglas County, Nebraska
# Processing record 319 | Cheshire County, New Hampshire
# Processing record 320 | Merrimack County, New Hampshire
# Processing record 321 | Grafton County, New Hampshire
# Processing record 322 | Rockingham County, New Hampshire
# Processing record 323 | Belknap County, New Hampshire
# Processing record 324 | Hillsborough County, New Hampshire
# Processing record 325 | Strafford County, New Hampshire
# Processing record 326 | Coos County, New Hampshire
# Processing record 406 | Mecklenburg County, North Carolina
# Processing record 407 | Pitt County, North Carolina
# Processing record 408 | Rowan County, North Carolina
# Processing record 409 | Vance County, North Carolina
# Processing record 410 | Currituck County, North Carolina
# Processing record 411 | Union County, North Carolina
# Processing record 412 | Wilkes County, North Carolina
# Processing record 413 | Forsyth County, North Carolina
# Processing record 414 | Dare County, North Carolina
# Processing record 415 | Carteret County, North Carolina
# Processing record 416 | Wilson County, North Carolina
# Processing record 417 | Randolph County, North Carolina
# Processing record 418 | Rockingham County, North Carolina
# Processing record 419 | Stokes County, North Carolina
# Processing record 420 | Cumberland County, North Carolina
# Processing record 421 | Gaston County, North Carolina
# Processing record 422 | Guilford County, North Carolina
# Processing record 423 | Moore County, North Carolina
# Processing record 424 | Robeson County, North Carolina
# Processing record 425 | Stanly County, North Carolina
# Processing record 426 | Wake County, North Carolina
# Processing record 427 | McDowell County, North Carolina
# Processing record 428 | Franklin County, North Carolina
# Processing record 429 | Johnston County, North Carolina
# Processing record 430 | Brunswick County, North Carolina
# Processing record 431 | Beaufort County, North Carolina
# Processing record 432 | Columbus County, North Carolina
# Processing record 433 | Lenoir County, North Carolina
# Processing record 434 | Onslow County, North Carolina
# Processing record 435 | Rutherford County, North Carolina
# Processing record 436 | Surry County, North Carolina
# Processing record 437 | Buncombe County, North Carolina
# Processing record 438 | Burke County, North Carolina
# Processing record 439 | Cabarrus County, North Carolina
# Processing record 440 | Davidson County, North Carolina
# Processing record 441 | Durham County, North Carolina
# Processing record 442 | Lee County, North Carolina
# Processing record 443 | New Hanover County, North Carolina
# Processing record 444 | Pender County, North Carolina
# Processing record 445 | Wayne County, North Carolina
# Processing record 446 | Cass County, North Dakota
# Processing record 447 | Gallia County, Ohio
# Processing record 448 | Huron County, Ohio
# Processing record 449 | Mahoning County, Ohio
# Processing record 450 | Adams County, Ohio
# Processing record 451 | Scioto County, Ohio
# Processing record 452 | Medina County, Ohio
# Processing record 453 | Union County, Ohio
# Processing record 454 | Champaign County, Ohio
# Processing record 455 | Pike County, Ohio
# Processing record 456 | Greene County, Ohio
# Processing record 457 | Hamilton County, Ohio
# Processing record 458 | Franklin County, Ohio
# Processing record 459 | Lawrence County, Ohio
# Processing record 460 | Marion County, Ohio
# Processing record 461 | Tuscarawas County, Ohio
# Processing record 462 | Wayne County, Ohio
# Processing record 463 | Brown County, Ohio
# Processing record 464 | Butler County, Ohio
# Processing record 465 | Erie County, Ohio
# Processing record 466 | Knox County, Ohio
# Processing record 467 | Licking County, Ohio
# Processing record 468 | Richland County, Ohio
# Processing record 469 | Hancock County, Ohio
# Processing record 470 | Clermont County, Ohio
# Processing record 471 | Fairfield County, Ohio
# Processing record 472 | Highland County, Ohio
# Processing record 473 | Jefferson County, Ohio
# Processing record 474 | Portage County, Ohio
# Processing record 475 | Clinton County, Ohio
# Processing record 476 | Fayette County, Ohio
# Processing record 477 | Logan County, Ohio
# Processing record 478 | Madison County, Ohio
# Processing record 479 | Summit County, Ohio
# Processing record 480 | Sandusky County, Ohio
# Processing record 481 | Shelby County, Ohio
# Processing record 482 | Washington County, Ohio
# Processing record 483 | Columbiana County, Ohio
# Processing record 484 | Darke County, Ohio
# Processing record 485 | Lucas County, Ohio
# Processing record 486 | Preble County, Ohio
# Processing record 487 | Seneca County, Ohio
# Processing record 488 | Stark County, Ohio
# Processing record 489 | Allen County, Ohio
# Processing record 490 | Crawford County, Ohio
# Processing record 491 | Delaware County, Ohio
# Processing record 492 | Geauga County, Ohio
# Processing record 493 | Lake County, Ohio
# Processing record 494 | Ross County, Ohio
# Processing record 495 | Clark County, Ohio
# Processing record 496 | Cuyahoga County, Ohio
# Processing record 497 | Lorain County, Ohio
# Processing record 498 | Miami County, Ohio
# Processing record 499 | Montgomery County, Ohio
# Processing record 500 | Trumbull County, Ohio
# Processing record 501 | Warren County, Ohio
# Processing record 502 | Wood County, Ohio
# Processing record 503 | Ashtabula County, Ohio
# Processing record 504 | Wagoner County, Oklahoma
# Processing record 505 | Cleveland County, Oklahoma
# Processing record 506 | Tulsa County, Oklahoma
# Processing record 507 | Oklahoma County, Oklahoma
# Processing record 508 | Marion County, Oregon
# Processing record 509 | Clackamas County, Oregon
# Processing record 510 | Josephine County, Oregon
# Processing record 511 | Lane County, Oregon
# Processing record 512 | Washington County, Oregon
# Processing record 513 | Multnomah County, Oregon
# Processing record 514 | Newport County, Rhode Island
# Processing record 515 | Kent County, Rhode Island
# Processing record 516 | Providence County, Rhode Island
# Processing record 517 | Washington County, Rhode Island
# Processing record 518 | Delaware County, Pennsylvania
# Processing record 519 | Franklin County, Pennsylvania
# Processing record 520 | Wayne County, Pennsylvania
# Processing record 521 | Dauphin County, Pennsylvania
# Processing record 522 | Somerset County, Pennsylvania
# Processing record 523 | Monroe County, Pennsylvania
# Processing record 524 | Philadelphia County, Pennsylvania
# Processing record 525 | York County, Pennsylvania
# Processing record 526 | Westmoreland County, Pennsylvania
# Processing record 527 | Blair County, Pennsylvania
# Processing record 528 | Cambria County, Pennsylvania
# Processing record 529 | Chester County, Pennsylvania
# Processing record 530 | Berks County, Pennsylvania
# Processing record 531 | Huntingdon County, Pennsylvania
# Processing record 532 | Indiana County, Pennsylvania
# Processing record 533 | Lawrence County, Pennsylvania
# Processing record 534 | Washington County, Pennsylvania
# Processing record 535 | Cumberland County, Pennsylvania
# Processing record 536 | Allegheny County, Pennsylvania
# Processing record 537 | Pike County, Pennsylvania
# Processing record 538 | Crawford County, Pennsylvania
# Processing record 539 | Erie County, Pennsylvania
# Processing record 540 | Schuylkill County, Pennsylvania
# Processing record 541 | Carbon County, Pennsylvania
# Processing record 542 | Centre County, Pennsylvania
# Processing record 543 | Northumberland County, Pennsylvania
# Processing record 544 | Northampton County, Pennsylvania
# Processing record 545 | Beaver County, Pennsylvania
# Processing record 546 | Bucks County, Pennsylvania
# Processing record 547 | Lackawanna County, Pennsylvania
# Processing record 548 | Lehigh County, Pennsylvania
# Processing record 549 | Fayette County, Pennsylvania
# Processing record 550 | Montgomery County, Pennsylvania
# Processing record 551 | Luzerne County, Pennsylvania
# Processing record 552 | Butler County, Pennsylvania
# Processing record 553 | Lancaster County, Pennsylvania
# Processing record 554 | Mercer County, Pennsylvania
# Processing record 555 | Aiken County, South Carolina
# Processing record 556 | Lexington County, South Carolina
# Processing record 557 | Oconee County, South Carolina
# Processing record 558 | Berkeley County, South Carolina
# Processing record 559 | Charleston County, South Carolina
# Processing record 560 | Georgetown County, South Carolina
# Processing record 561 | York County, South Carolina
# Processing record 562 | Anderson County, South Carolina
# Processing record 563 | Greenwood County, South Carolina
# Processing record 564 | Horry County, South Carolina
# Processing record 565 | Spartanburg County, South Carolina
# Processing record 566 | Beaufort County, South Carolina
# Processing record 567 | Richland County, South Carolina
# Processing record 568 | Greenville County, South Carolina
# Processing record 569 | Lancaster County, South Carolina
# Processing record 570 | Dorchester County, South Carolina
# Processing record 571 | Florence County, South Carolina
# Processing record 572 | Pickens County, South Carolina
# Processing record 573 | Davidson County, Tennessee
# Processing record 574 | Roane County, Tennessee
# Processing record 575 | Bradley County, Tennessee
# Processing record 576 | Maury County, Tennessee
# Processing record 577 | Montgomery County, Tennessee
# Processing record 578 | Knox County, Tennessee
# Processing record 579 | Tipton County, Tennessee
# Processing record 580 | Anderson County, Tennessee
# Processing record 581 | Hamilton County, Tennessee
# Processing record 582 | Loudon County, Tennessee
# Processing record 583 | Rutherford County, Tennessee
# Processing record 584 | Wilson County, Tennessee
# Processing record 585 | Sullivan County, Tennessee
# Processing record 586 | Washington County, Tennessee
# Processing record 587 | Coffee County, Tennessee
# Processing record 588 | Robertson County, Tennessee
# Processing record 589 | Blount County, Tennessee
# Processing record 590 | Cheatham County, Tennessee
# Processing record 591 | Carter County, Tennessee
# Processing record 592 | Sumner County, Tennessee
# Processing record 593 | Williamson County, Tennessee
# Processing record 594 | Greene County, Tennessee
# Processing record 595 | Shelby County, Tennessee
# Processing record 596 | Sevier County, Tennessee
# Processing record 597 | Ector County, Texas
# Processing record 598 | Travis County, Texas
# Processing record 599 | Collin County, Texas
# Processing record 600 | Tarrant County, Texas
# Processing record 601 | Nueces County, Texas
# Processing record 602 | Randall County, Texas
# Processing record 603 | Brazoria County, Texas
# Processing record 604 | Williamson County, Texas
# Processing record 605 | Doña Ana County, New Mexico
# Processing record 606 | Lubbock County, Texas
# Processing record 607 | Bexar County, Texas
# Processing record 608 | Bell County, Texas
# Processing record 609 | Denton County, Texas
# Processing record 610 | Harris County, Texas
# Processing record 611 | Dallas County, Texas
# Processing record 612 | Johnson County, Texas
# Processing record 613 | Montgomery County, Texas
# Processing record 614 | Webb County, Texas
# Processing record 615 | Fort Bend County, Texas
# Processing record 616 | Jefferson County, Texas
# Processing record 617 | Galveston County, Texas
# Processing record 618 | El Paso County, Texas
# Processing record 619 | Tooele County, Utah
# Processing record 620 | Washington County, Utah
# Processing record 621 | Utah County, Utah
# Processing record 622 | Weber County, Utah
# Processing record 623 | Salt Lake County, Utah
# Processing record 624 | Davis County, Utah
# Processing record 625 | Cache County, Utah
# Processing record 626 | Rutland County, Vermont
# Processing record 627 | Chittenden County, Vermont
# Processing record 628 | Windsor County, Vermont
# Processing record 629 | Franklin County, Vermont
# Processing record 630 | Windham County, Vermont
# Processing record 631 | Washington County, Vermont
# Processing record 632 | Culpeper County, Virginia
# Processing record 633 | Hanover County, Virginia
# Processing record 634 | Chesapeake city, Virginia
# Processing record 635 | Bedford County, Virginia
# Processing record 636 | Wise County, Virginia
# Processing record 637 | Portsmouth city, Virginia
# Processing record 638 | Virginia Beach city, Virginia
# Processing record 639 | Warren County, Virginia
# Processing record 640 | Alexandria city, Virginia
# Processing record 641 | Hampton city, Virginia
# Processing record 642 | Arlington County, Virginia
# Processing record 643 | Hopewell city, Virginia
# Processing record 644 | Newport News city, Virginia
# Processing record 645 | Frederick County, Virginia
# Processing record 646 | Stafford County, Virginia
# Processing record 647 | Richmond city, Virginia
# Processing record 648 | Tazewell County, Virginia
# Processing record 649 | Petersburg city, Virginia
# Processing record 650 | Roanoke city, Virginia
# Processing record 651 | Norfolk city, Virginia
# Processing record 652 | Chesterfield County, Virginia
# Processing record 653 | Fairfax County, Virginia
# Processing record 654 | Henrico County, Virginia
# Processing record 655 | King George County, Virginia
# Processing record 656 | Spotsylvania County, Virginia
# Processing record 657 | Montgomery County, Virginia
# Processing record 658 | Augusta County, Virginia
# Processing record 659 | Loudoun County, Virginia
# Processing record 660 | Prince William County, Virginia
# Processing record 661 | Roanoke County, Virginia
# Processing record 662 | Fauquier County, Virginia
# Processing record 663 | Harrison County, West Virginia
# Processing record 664 | Ohio County, West Virginia
# Processing record 665 | Morgan County, West Virginia
# Processing record 666 | Lincoln County, West Virginia
# Processing record 667 | Raleigh County, West Virginia
# Processing record 668 | Putnam County, West Virginia
# Processing record 669 | Boone County, West Virginia
# Processing record 670 | McDowell County, West Virginia
# Processing record 671 | Wayne County, West Virginia
# Processing record 672 | Mercer County, West Virginia
# Processing record 673 | Berkeley County, West Virginia
# Processing record 674 | Fayette County, West Virginia
# Processing record 675 | Hampshire County, West Virginia
# Processing record 676 | Mingo County, West Virginia
# Processing record 677 | Hancock County, West Virginia
# Processing record 678 | Wood County, West Virginia
# Processing record 679 | Mason County, West Virginia
# Processing record 680 | Monongalia County, West Virginia
# Processing record 681 | Cabell County, West Virginia
# Processing record 682 | Jefferson County, West Virginia
# Processing record 683 | Kanawha County, West Virginia
# Processing record 684 | Logan County, West Virginia
# Processing record 685 | Thurston County, Washington
# Processing record 686 | Benton County, Washington
# Processing record 687 | Clark County, Washington
# Processing record 688 | Skagit County, Washington
# Processing record 689 | Spokane County, Washington
# Processing record 690 | Kitsap County, Washington
# Processing record 691 | King County, Washington
# Processing record 692 | Yakima County, Washington
# Processing record 693 | Cowlitz County, Washington
# Processing record 694 | Grays Harbor County, Washington
# Processing record 695 | Island County, Washington
# Processing record 696 | Pierce County, Washington
# Processing record 697 | Walla Walla County, Washington
# Processing record 698 | Whatcom County, Washington
# Processing record 699 | Snohomish County, Washington
# Processing record 700 | Rock County, Wisconsin
# Processing record 701 | Jefferson County, Wisconsin
# Processing record 702 | Kenosha County, Wisconsin
# Processing record 703 | Milwaukee County, Wisconsin
# Processing record 704 | Racine County, Wisconsin
# Processing record 705 | Winnebago County, Wisconsin
# Processing record 706 | Sheboygan County, Wisconsin
# Processing record 707 | Outagamie County, Wisconsin
# Processing record 708 | Columbia County, Wisconsin
# Processing record 709 | La Crosse County, Wisconsin
# Processing record 710 | Brown County, Wisconsin
# Processing record 711 | Marathon County, Wisconsin
# Processing record 712 | Waukesha County, Wisconsin
# Processing record 713 | Dodge County, Wisconsin
# Processing record 714 | Walworth County, Wisconsin
# Processing record 715 | Washington County, Wisconsin
# Processing record 716 | Dane County, Wisconsin
# Processing record 717 | Ozaukee County, Wisconsin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#            0          1
# 0  33.491412 -86.982429
# 1  33.303929 -86.661108
# 2  33.653011 -86.337676
# 3  30.601074 -87.776333
# 4  34.201154 -86.822034

# %%
# counties_df[0]

coordinates = counties_df.astype(float)
coordinates.to_csv("coordinates.csv", encoding="utf-8", index=False)

coordinates_csv = pd.read_csv("coordinates.csv", dtype="float", encoding="utf-8")

# %%
deaths_100K = new_merged_df["Per 100K"].astype(float)

# %%
fig = gmaps.figure()
colors = ("maroon","red","yellow","green","blue","teal")
heat_layer = gmaps.heatmap_layer(coordinates_csv, weights=deaths_100K, 
                                 dissipating=False,
                                 point_radius = 0.5,opacity=0.5)


fig.add_layer(heat_layer)

# %%
 # Convert bank rate to list
deaths_list = new_merged_df["Deaths"].tolist()

# %%
for index, row in new_merged_df.iterrows():

    county_name = row['County Name']
    deaths = row['Deaths']
#     print(county_name)
#     print(deaths)
    print(f'{county_name}')
# Out:
# Jefferson County, Alabama
# 167
# Shelby County, Alabama
# 27
# St. Clair County, Alabama
# 15
# Baldwin County, Alabama
# 19
# Cullman County, Alabama
# 12
# Tuscaloosa County, Alabama
# 14
# Etowah County, Alabama
# 26
# DeKalb County, Alabama
# 11
# Mobile County, Alabama
# 13
# Madison County, Alabama
# 16
# Matanuska-Susitna Borough, Alaska
# 20
# Juneau City and Borough, Alaska
# 11
# Anchorage Municipality, Alaska
# 49
# Pima County, Arizona
# 174
# Maricopa County, Arizona
# 631
# Cochise County, Arizona
# 17
# Yavapai County, Arizona
# 22
# Pinal County, Arizona
# 34
# Pulaski County, Arkansas
# 31
# Saline County, Arkansas
# 12
# Benton County, Arkansas
# 14
# Garland County, Arkansas
# 17
# Merced County, California
# 14
# Lake County, California
# 16
# Contra Costa County, California
# 53
# Stanislaus County, California
# 17
# Santa Barbara County, California
# 27
# Sonoma County, California
# 32
# Alameda County, California
# 35
# Sacramento County, California
# 59
# San Diego County, California
# 283
# San Francisco County, California
# 102
# Humboldt County, California
# 27
# Mendocino County, California
# 19
# Santa Cruz County, California
# 19
# Los Angeles County, California
# 464
# Riverside County, California
# 134
# San Bernardino County, California
# 56
# Santa Clara County, California
# 67
# Marin County, California
# 15
# Placer County, California
# 18
# Shasta County, California
# 28
# Solano County, California
# 10
# Butte County, California
# 16
# San Luis Obispo County, California
# 15
# Fresno County, California
# 41
# Kern County, California
# 82
# Orange County, California
# 258
# Ventura County, California
# 88
# San Mateo County, California
# 41
# San Joaquin County, California
# 75
# Adams County, Colorado
# 77
# Larimer County, Colorado
# 28
# Boulder County, Colorado
# 24
# Pueblo County, Colorado
# 29
# Mesa County, Colorado
# 33
# 11

# %%
# Create death symbol layer
death_county = []
nl = '\n'
for index, row in new_merged_df.iterrows():
    county_name = row['County Name']
    deaths = row['Deaths']
#     print(county_name)
#     print(deaths)
#     print(f'{county_name}')
    death_county.append ( [f"2017 {county_name} \nOpioid Related Deaths: {death}" for death in deaths])
    

deaths_layer = gmaps.symbol_layer(
    coordinates, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=1,
    info_box_content=[f"2017 Opioid Related Deaths: \n{row}" for row in deaths_list]
#     info_box_content = death_county
)


fig = gmaps.figure()
fig.add_layer(deaths_layer)




# ---------------------------------------------------

# ['FIPS Code',
#  'County_x',
#  'State',
#  'County Name',
#  'Population_x',
#  'Household Income',
#  'Per Capita Income',
#  'Poverty Count',
#  'Poverty Rate',
#  'Unemployment Count',
#  'Unemployment Rate',
#  'County_y',
#  'Deaths',
#  'Population_y',
#  'Crude Rate',
#  '% of Total Deaths',
#  'Per 100K']

# %%
# Create a combined map
fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(deaths_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
sorted_deaths_df = CDC_Table.sort_values("Deaths", ascending=False)
top_10_df_deaths = sorted_deaths_df.head(10)


sd_df = CDC_Table[CDC_Table['County'] == 'San Diego County, CA']
sd_df['Deaths'] = sd_df['Deaths'].astype(int)

top_10_df_deaths = top_10_df_deaths.append(sd_df)



x_axis = np.arange(0, len(top_10_df_deaths))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Top 10 Counties in Opioid-related Deaths 2017")
plt.xlabel("County")
plt.ylabel("Number of Opioid-related Deaths")

plt.xlim(-0.75, len(top_10_df_deaths)-.25)
plt.ylim(0, max(top_10_df_deaths['Deaths']) + 5)

plt.bar(x_axis, top_10_df_deaths['Deaths'], facecolor="blue", alpha=0.75, align="center")
plt.xticks(tick_locations, top_10_df_deaths['County'],rotation=90)
plt.savefig("BarDeaths.png")
plt.show()
# Out:
# C:\Users\jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_merged_df['Per 100K'] = new_merged_df['Per 100K'].astype(float)
sorted_deathrate_df = new_merged_df.sort_values("Per 100K", ascending=False)
top_10_df_rate = sorted_deathrate_df.head(10)



sd_rate_df = new_merged_df[new_merged_df['County_y'] == 'San Diego County, CA']
sd_rate_df['Per 100K'] = sd_rate_df['Per 100K'].astype(float)
sd_rate_df
top_10_df_rate = pd.concat([top_10_df_rate, sd_rate_df])
top_10_df_rate

x_axis = np.arange(0, len(top_10_df_rate))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Top 10 Counties in Opioid-related Deaths Rate")
plt.xlabel("County")
plt.ylabel("Number of Opioid-related Deaths per 100K people")

plt.xlim(-0.75, len(top_10_df_deaths)-.25)
plt.ylim(0, max(top_10_df_rate['Per 100K']) + 5)

plt.bar(x_axis, top_10_df_rate['Per 100K'], facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, top_10_df_rate['County_y'],rotation=90)
plt.savefig("BarDeathRate.png")
plt.show()
# Out:
# C:\Users\jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
