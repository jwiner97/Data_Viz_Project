# %% [markdown]
# Identify the 10 areas most impacted by the Great Recession. Determine how to track opioid usage in those areas.
#
# Look at the opioid overdose and fatality information over time (2006-2018)
# Create a line graph with the information.
#
#
# Create the following:
# Bar Graph of the change in opioid deaths by county
# State vs County Bar Graph
# Heat Map of the counties to show the intensity
#
# Resources:
# Death over time by county
# Unemployment 2006 - 2018
# Opioid deaths for each state 1999-2017

# %% [markdown]
# Counties
# Saginaw County, MI
# Richland County, OH
# Mahoning County, OH
# Iberia Parish, LA
# Lake County, IN
# Mohave County, AZ
# Cook County, IL
# Trumbull County, OH
# Wayne County, MI
# Genessee County, MI

# %%
# Import Dependents
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Define Files
county_deaths = 'Resources/Multiple Cause of Death Opioits 2006-2017 (3).csv'
unemployment_rate06 = 'Resources/laucnty06.csv'
unemployment_rate07 = 'Resources/laucnty07.csv'
unemployment_rate08 = 'Resources/laucnty08.csv'
unemployment_rate09 = 'Resources/laucnty09.csv'
unemployment_rate10 = 'Resources/laucnty10.csv'
unemployment_rate11 = 'Resources/laucnty11.csv'
unemployment_rate12 = 'Resources/laucnty12.csv'
unemployment_rate13 = 'Resources/laucnty13.csv'
unemployment_rate14 = 'Resources/laucnty14.csv'
unemployment_rate15 = 'Resources/laucnty15.csv'
unemployment_rate16 = 'Resources/laucnty16.csv'
unemployment_rate17 = 'Resources/laucnty17.csv'
state_deaths17 = "Resources/KFF Opioid Deaths by State 2017.csv"
state_deaths_over_time = "Resources/Deaths 99-17.csv"

# %%
unemployment_files = {
    2006: 'Resources/laucnty06.csv',
    2007: 'Resources/laucnty07.csv',
    2008: 'Resources/laucnty08.csv',
    2009: 'Resources/laucnty09.csv',
    2010: 'Resources/laucnty10.csv',
    2011: 'Resources/laucnty11.csv',
    2012: 'Resources/laucnty12.csv',
    2013: 'Resources/laucnty13.csv',
    2014: 'Resources/laucnty14.csv',
    2015: 'Resources/laucnty15.csv',
    2016: 'Resources/laucnty16.csv',
    2017: 'Resources/laucnty17.csv'
}

# %%
dfs = []
for year, filename in unemployment_files.items():
    df = pd.read_csv(filename, skiprows=4)
    df['year'] = year
    dfs.append(df)

# %%
full_data = pd.concat(dfs)
full_data.tail()
# Out:
#                     Code  Code.1  Code.2 County Name/State Abbreviation  \
# 3218     CN7215100000000    72.0   151.0          Yabucoa Municipio, PR
# 3219     CN7215300000000    72.0   153.0            Yauco Municipio, PR
# 3220                 NaN     NaN     NaN                            NaN
# 3221  SOURCE:  BLS, LAUS     NaN     NaN                            NaN
# 3222   February 28, 2019     NaN     NaN                            NaN
#
#         Year  Unnamed: 5        Force    Employed  Unemployed   (%)  year
# 3218  2017.0         NaN   9,010       7,533       1,477       16.4  2017
# 3219  2017.0         NaN  10,276       8,498       1,778       17.3  2017
# 3220     NaN         NaN          NaN         NaN         NaN   NaN  2017
# 3221     NaN         NaN          NaN         NaN         NaN   NaN  2017
# 3222     NaN         NaN          NaN         NaN         NaN   NaN  2017

# %%
full_data.set_index('County Name/State Abbreviation', inplace=True)
full_data.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2006.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2006.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2006.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2006.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  24,398       23,585
# Baldwin County, AL                     NaN  79,711       77,147
# Barbour County, AL                     NaN  10,705       10,096
# Bibb County, AL                        NaN   8,850        8,477
#
#                                 Unemployed       (%)  year
# ...

# %%
UE_df = full_data.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

UE_df = UE_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

UE_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                       Force     Employed   Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ               92,888       88,852        4,036
# Mohave County, AZ               91,440       87,174        4,266
# Mohave County, AZ               92,592       85,485        7,107
# Mohave County, AZ               91,554       81,120       10,434
# Mohave County, AZ               82,726       71,999       10,727
#
#                                      (%)    year
# County Name/State Abbreviation
# Mohave County, AZ               4.3       2006.0
# ...

# %%
Primary_UE_df = UE_df.drop(["Force", "Employed", "Unemployed"], axis=1)
print(Primary_UE_df)
# Out:
#                                      (%)    year
# County Name/State Abbreviation
# Mohave County, AZ               4.3       2006.0
# Mohave County, AZ                    4.7  2007.0
# Mohave County, AZ                    7.7  2008.0
# Mohave County, AZ                   11.4  2009.0
# Mohave County, AZ                     13  2010.0
# Mohave County, AZ                   12.3  2011.0
# Mohave County, AZ                     11  2012.0
# Mohave County, AZ                   10.3  2013.0
# Mohave County, AZ                    8.7  2014.0
# Mohave County, AZ                    7.9  2015.0
# Mohave County, AZ                    6.6  2016.0
# Mohave County, AZ                    5.9  2017.0
# Cook County, IL                 4.9       2006.0
# Cook County, IL                      5.3  2007.0
# Cook County, IL                      6.4  2008.0
# Cook County, IL                     10.5  2009.0
# Cook County, IL                     10.9  2010.0
# ...

# %%
peter_df = Primary_UE_df.reset_index()
peter_df.head()
# Out:
#   County Name/State Abbreviation       (%)    year
# 0              Mohave County, AZ  4.3       2006.0
# 1              Mohave County, AZ       4.7  2007.0
# 2              Mohave County, AZ       7.7  2008.0
# 3              Mohave County, AZ      11.4  2009.0
# 4              Mohave County, AZ        13  2010.0

# %%
peter_df['(%)'] = peter_df['(%)'].astype('float64')

# %%
p = peter_df.set_index('year')

# %%
p.head(20)
# Out:
#        County Name/State Abbreviation   (%)
# year
# 2006.0              Mohave County, AZ   4.3
# 2007.0              Mohave County, AZ   4.7
# 2008.0              Mohave County, AZ   7.7
# 2009.0              Mohave County, AZ  11.4
# 2010.0              Mohave County, AZ  13.0
# 2011.0              Mohave County, AZ  12.3
# 2012.0              Mohave County, AZ  11.0
# 2013.0              Mohave County, AZ  10.3
# 2014.0              Mohave County, AZ   8.7
# 2015.0              Mohave County, AZ   7.9
# 2016.0              Mohave County, AZ   6.6
# 2017.0              Mohave County, AZ   5.9
# 2006.0                Cook County, IL   4.9
# 2007.0                Cook County, IL   5.3
# 2008.0                Cook County, IL   6.4
# 2009.0                Cook County, IL  10.5
# 2010.0                Cook County, IL  10.9
# 2011.0                Cook County, IL  10.4
# 2012.0                Cook County, IL   9.6
# 2013.0                Cook County, IL   9.6

# %%
p.plot(kind='line')

# %%
# pd.pivot_table(data, index= 'Year', values= "Happiness Score")
Unemployment = pd.pivot_table(peter_df, index='year', values='(%)', columns='County Name/State Abbreviation')

# %%
Unemployment
# Out:
# County Name/State Abbreviation  Cook County, IL  Iberia Parish, LA  \
# year
# 2006.0                                      4.9                3.8
# 2007.0                                      5.3                3.7
# 2008.0                                      6.4                4.3
# 2009.0                                     10.5                6.9
# 2010.0                                     10.9                8.6
# 2011.0                                     10.4                7.9
# 2012.0                                      9.6                6.8
# 2013.0                                      9.6                6.5
# 2014.0                                      7.5                6.3
# 2015.0                                      6.2                8.1
# 2016.0                                      6.1                9.4
# 2017.0                                      5.2                7.3
#
# County Name/State Abbreviation  Lake County, IN  Mahoning County, OH  \
# year
# ...

# %%
Unemployment.plot()

# %%
Primary_UE_df.plot.line(x="year", y="(%)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-9820eaaa2e2d> in <module>
# ----> 1 Primary_UE_df.plot.line(x="year", y="(%)")
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwds)
#    3003             >>> lines = df.plot.line(x='pig', y='horse')
#    3004         """
# -> 3005         return self(kind='line', x=x, y=y, **kwds)
#    3006
#    3007     def bar(self, x=None, y=None, **kwds):
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
# Create Dataframes
unemployment_rate06_df = pd.read_csv(unemployment_rate06, skiprows=4)
unemployment_rate07_df = pd.read_csv(unemployment_rate07, skiprows=4)
unemployment_rate08_df = pd.read_csv(unemployment_rate08, skiprows=4)
unemployment_rate09_df = pd.read_csv(unemployment_rate09, skiprows=4)
unemployment_rate10_df = pd.read_csv(unemployment_rate10, skiprows=4)
unemployment_rate11_df = pd.read_csv(unemployment_rate11, skiprows=4)
unemployment_rate12_df = pd.read_csv(unemployment_rate12, skiprows=4)
unemployment_rate13_df = pd.read_csv(unemployment_rate13, skiprows=4)
unemployment_rate14_df = pd.read_csv(unemployment_rate14, skiprows=4)
unemployment_rate15_df = pd.read_csv(unemployment_rate15, skiprows=4)
unemployment_rate16_df = pd.read_csv(unemployment_rate16, skiprows=4)
unemployment_rate17_df = pd.read_csv(unemployment_rate17,skiprows=4)
state_deaths17_df = pd.read_csv(state_deaths17, skiprows=2)
deaths_OT_df = pd.read_csv(state_deaths_over_time, skiprows=2)
county_deaths_df = pd.read_csv(county_deaths)

state_deaths17_df
# Out:
#                                              Location  \
# 0                                       United States
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# 5                                          California
# 6                                            Colorado
# 7                                         Connecticut
# 8                                            Delaware
# 9                                District of Columbia
# 10                                            Florida
# 11                                            Georgia
# 12                                             Hawaii
# 13                                              Idaho
# 14                                           Illinois
# 15                                            Indiana
# ...

# %%
#Set Index State Deaths
state_deaths17_df.set_index('Location', inplace=True)

state_deaths17_df.head()
# Out:
#                Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                       14.9
# Alabama                                              9.0
# Alaska                                              13.9
# Arizona                                             13.5
# Arkansas                                             6.5
#
#                All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                         21.7
# Alabama                                               18.0
# Alaska                                                20.2
# Arizona                                               22.2
# Arkansas                                              15.5
#
#                Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                               0.12
# Alabama                                                     0.20
# ...

# %%
# Pull State Death Data
key_sd17_df = state_deaths17_df.loc[['Arizona', 'Illinois', 'Indiana', 'Louisiana', 'Michigan', 'Ohio']]

# %%
key_sd17_df.head()
# Out:
#            Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# Arizona                                         13.5
# Illinois                                        17.2
# Indiana                                         18.8
# Louisiana                                        9.3
# Michigan                                        21.2
#
#            All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# Arizona                                           22.2
# Illinois                                          21.6
# Indiana                                           29.4
# Louisiana                                         24.5
# Michigan                                          27.8
#
#            Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# Arizona                                                 0.18
# Illinois                                                0.12
# Indiana                                                 0.49
# ...

# %%
# Set Index State Deaths Over Time Data Frames
deaths_OT_df.set_index('Location', inplace=True)
deaths_OT_df.head()
# Out:
#               1999__Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                             2.9
# Alabama                                                   0.8
# Alaska                                                      4
# Arizona                                                   4.7
# Arkansas                                                  1.1
#
#               1999__Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# United States                                                NSD
# Alabama                                                      NSD
# Alaska                                                       NSD
# Arizona                                                      NSD
# Arkansas                                                     NSD
#
#               2000__Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# United States                                               3
# ...

# %%
#Pull Primary States from Deaths OT Data Frame
key_DOT_df = deaths_OT_df.loc[['Arizona', 'Illinois', 'Indiana', 'Louisiana', 'Michigan', 'Ohio']]
key_DOT_df.head()
# Out:
#           1999__Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# Arizona                                               4.7
# Illinois                                              3.9
# Indiana                                               0.8
# Louisiana                                             0.7
# Michigan                                              1.2
#
#           1999__Percent Change in Opioid Overdose Death Rate from Prior Year  \
# Location
# Arizona                                                  NSD
# Illinois                                                 NSD
# Indiana                                                  NSD
# Louisiana                                                NSD
# Michigan                                                 NSD
#
#           2000__Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# Arizona                                               4.8
# Illinois                                              4.5
# ...

# %%
#Set Unemployement Index
unemployment_rate06_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate06_df.head()

#unemployment_rate17_df.set_index('County Name/State Abbreviation', inplace=True)

#unemployment_rate17_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2006.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2006.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2006.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2006.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  24,398       23,585
# Baldwin County, AL                     NaN  79,711       77,147
# Barbour County, AL                     NaN  10,705       10,096
# Bibb County, AL                        NaN   8,850        8,477
#
#                                 Unemployed       (%)
# ...

# %%
# Pull out the focus counties from Unemployment Data Frame 2006
key_UE06_df = unemployment_rate06_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE06_df = key_UE06_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE06_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # This is added back by InteractiveShellApp.init_path()
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  92,888          88,852         4,036
# Cook County, IL                 2,566,657       2,441,887       124,770
# Lake County, IN                   227,320         214,057        13,263
# Iberia Parish, LA                  34,260          32,954         1,306
# Genessee County, MI                        NaN             NaN           NaN
#
#                                      (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate07_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate07_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County Name/State Abbreviation'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-27329ea2b0d0> in <module>
# ...

# %%
key_UE07_df = unemployment_rate07_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE07_df = key_UE07_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE07_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  91,440          87,174         4,266
# Cook County, IL                 2,615,750       2,478,215       137,535
# Lake County, IN                   226,108         214,416        11,692
# Iberia Parish, LA                  34,429          33,154         1,275
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               4.7
# ...

# %%
unemployment_rate08_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate08_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2008.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2008.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2008.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2008.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  24,687       23,420
# Baldwin County, AL                     NaN  83,223       79,372
# Barbour County, AL                     NaN  10,161        9,267
# Bibb County, AL                        NaN   8,749        8,241
#
#                                 Unemployed  (%)
# ...

# %%
key_UE08_df = unemployment_rate08_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE08_df = key_UE08_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE08_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  92,592          85,485         7,107
# Cook County, IL                 2,615,675       2,447,178       168,497
# Lake County, IN                   228,369         214,202        14,167
# Iberia Parish, LA                  35,239          33,729         1,510
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               7.7
# ...

# %%
unemployment_rate09_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate09_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2009.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2009.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2009.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2009.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  24,703       22,301
# Baldwin County, AL                     NaN  82,451       74,403
# Barbour County, AL                     NaN  10,003        8,572
# Bibb County, AL                        NaN   8,742        7,581
#
#                                 Unemployed   (%)
# ...

# %%
key_UE09_df = unemployment_rate09_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE09_df = key_UE09_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE09_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  91,554          81,120        10,434
# Cook County, IL                 2,604,692       2,330,033       274,659
# Lake County, IN                   226,034         201,966        24,068
# Iberia Parish, LA                  34,245          31,889         2,356
# Genessee County, MI                        NaN             NaN           NaN
#
#                                  (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate10_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate10_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2010.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2010.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2010.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2010.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,713       23,431
# Baldwin County, AL                     NaN  83,459       75,120
# Barbour County, AL                     NaN  10,221        8,959
# Bibb County, AL                        NaN   8,934        7,914
#
#                                 Unemployed   (%)
# ...

# %%
key_UE10_df = unemployment_rate10_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE10_df = key_UE10_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE10_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  82,726          71,999        10,727
# Cook County, IL                 2,643,833       2,356,472       287,361
# Lake County, IN                   229,124         204,390        24,734
# Iberia Parish, LA                  32,240          29,464         2,776
# Genessee County, MI                        NaN             NaN           NaN
#
#                                  (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate11_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate11_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2011.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2011.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2011.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2011.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,836       23,677
# Baldwin County, AL                     NaN  85,045       77,418
# Barbour County, AL                     NaN   9,849        8,712
# Bibb County, AL                        NaN   8,933        7,996
#
#                                 Unemployed   (%)
# ...

# %%
key_UE11_df = unemployment_rate11_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE11_df = key_UE11_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE11_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  79,594          69,823         9,771
# Cook County, IL                 2,636,434       2,360,934       275,500
# Lake County, IN                   229,318         207,352        21,966
# Iberia Parish, LA                  31,877          29,358         2,519
# Genessee County, MI                        NaN             NaN           NaN
#
#                                  (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate12_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate12_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2012.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2012.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2012.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2012.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,740       23,961
# Baldwin County, AL                     NaN  84,414       78,065
# Barbour County, AL                     NaN   9,362        8,283
# Bibb County, AL                        NaN   8,798        8,047
#
#                                 Unemployed   (%)
# ...

# %%
key_UE12_df = unemployment_rate12_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE12_df = key_UE12_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE12_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  77,570          69,021         8,549
# Cook County, IL                 2,653,326       2,397,792       255,534
# Lake County, IN                   228,880         208,007        20,873
# Iberia Parish, LA                  32,236          30,056         2,180
# Genessee County, MI                        NaN             NaN           NaN
#
#                                  (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate13_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate13_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2013.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2013.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2013.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2013.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,810       24,205
# Baldwin County, AL                     NaN  85,280       79,626
# Barbour County, AL                     NaN   9,099        8,168
# Bibb County, AL                        NaN   8,705        8,016
#
#                                 Unemployed   (%)
# ...

# %%
key_UE13_df = unemployment_rate13_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE13_df = key_UE13_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE13_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  76,838          68,888         7,950
# Cook County, IL                 2,671,904       2,414,722       257,182
# Lake County, IN                   229,941         209,097        20,844
# Iberia Parish, LA                  32,283          30,200         2,083
# Genessee County, MI                        NaN             NaN           NaN
#
#                                  (%)
# County Name/State Abbreviation
# ...

# %%
unemployment_rate14_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate14_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2014.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2014.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2014.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2014.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,602       24,107
# Baldwin County, AL                     NaN  86,415       81,115
# Barbour County, AL                     NaN   8,848        7,916
# Bibb County, AL                        NaN   8,562        7,945
#
#                                 Unemployed   (%)
# ...

# %%
key_UE14_df = unemployment_rate14_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE14_df = key_UE14_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE14_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  78,060          71,264         6,796
# Cook County, IL                 2,653,342       2,455,149       198,193
# Lake County, IN                   230,390         212,208        18,182
# Iberia Parish, LA                  32,610          30,546         2,064
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               8.7
# ...

# %%
unemployment_rate15_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate15_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2015.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2015.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2015.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2015.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,602       24,272
# Baldwin County, AL                     NaN  87,705       82,843
# Barbour County, AL                     NaN   8,609        7,844
# Bibb County, AL                        NaN   8,572        8,005
#
#                                 Unemployed  (%)
# ...

# %%
key_UE15_df = unemployment_rate15_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE15_df = key_UE15_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE15_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  79,210          72,935         6,275
# Cook County, IL                 2,648,861       2,484,494       164,367
# Lake County, IN                   229,689         214,013        15,676
# Iberia Parish, LA                  31,878          29,291         2,587
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               7.9
# ...

# %%
unemployment_rate16_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate16_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2016.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2016.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2016.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2016.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,918       24,593
# Baldwin County, AL                     NaN  90,500       85,656
# Barbour County, AL                     NaN   8,402        7,700
# Bibb County, AL                        NaN   8,607        8,050
#
#                                 Unemployed  (%)
# ...

# %%
key_UE16_df = unemployment_rate16_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                         'Saginaw County, MI',
                                         'Wayne County, MI',
                                         'Mahoning County, OH',
                                         'Richland County, OH',
                                         'Trumbull County, OH']]

key_UE16_df = key_UE16_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE16_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   # Remove the CWD from sys.path while we load stuff.
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  80,139          74,844         5,295
# Cook County, IL                 2,669,585       2,507,250       162,335
# Lake County, IN                   232,103         217,432        14,671
# Iberia Parish, LA                  30,177          27,352         2,825
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               6.6
# ...

# %%
unemployment_rate17_df.set_index('County Name/State Abbreviation', inplace=True)
unemployment_rate17_df.head()
# Out:
#                                            Code  Code.1  Code.2    Year  \
# County Name/State Abbreviation
# NaN                                         NaN     NaN     NaN     NaN
# Autauga County, AL              CN0100100000000     1.0     1.0  2017.0
# Baldwin County, AL              CN0100300000000     1.0     3.0  2017.0
# Barbour County, AL              CN0100500000000     1.0     5.0  2017.0
# Bibb County, AL                 CN0100700000000     1.0     7.0  2017.0
#
#                                 Unnamed: 5        Force     Employed  \
# County Name/State Abbreviation
# NaN                                    NaN          NaN          NaN
# Autauga County, AL                     NaN  25,909       24,908
# Baldwin County, AL                     NaN  91,567       87,915
# Barbour County, AL                     NaN   8,236        7,750
# Bibb County, AL                        NaN   8,506        8,133
#
#                                 Unemployed  (%)
# ...

# %%
# Pull out the focus counties from Unemployment Data Frame 2017

#unemployment_rate17_df.set_index('County Name/State Abbreviation', inplace=True)

key_UE17_df = unemployment_rate17_df.loc[['Mohave County, AZ',
                                          'Cook County, IL',
                                          'Lake County, IN',
                                          'Iberia Parish, LA',
                                          'Genessee County, MI',
                                          'Saginaw County, MI',
                                          'Wayne County, MI',
                                          'Mahoning County, OH',
                                          'Richland County, OH',
                                          'Trumbull County, OH']]

key_UE17_df = key_UE17_df.drop(["Code", "Code.1", "Code.2", "Year", "Unnamed: 5"], axis=1)

key_UE17_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#                                          Force        Employed    Unemployed  \
# County Name/State Abbreviation
# Mohave County, AZ                  82,407          77,579         4,828
# Cook County, IL                 2,653,153       2,514,113       139,040
# Lake County, IN                   229,520         217,832        11,688
# Iberia Parish, LA                  29,495          27,351         2,144
# Genessee County, MI                        NaN             NaN           NaN
#
#                                 (%)
# County Name/State Abbreviation
# Mohave County, AZ               5.9
# Cook County, IL                 5.2
# ...

# %%
# Create Data Frame of Unemployment % over time
UE_OT_df = pd.concat([key_UE06_df, 
                     key_UE07_df, 
                     key_UE08_df, 
                     key_UE09_df, 
                     key_UE10_df, 
                     key_UE11_df, 
                     key_UE12_df, 
                     key_UE13_df, 
                     key_UE14_df, 
                     key_UE15_df, 
                     key_UE16_df, 
                     key_UE17_df],
#                     [['County Name/State Abbreviation','(%)']], 
                    on='County Name/State Abbreviation')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-8aaee88a0b7c> in <module>
#      13                      key_UE17_df],
#      14 #                     [['County Name/State Abbreviation','(%)']],
# ---> 15                     on='County Name/State Abbreviation')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
# Group County Death Data
county_deaths_df.groupby(['County', 'Year'])[['Deaths']].sum()
# Out:
#                           Deaths
# County              Year
# Cook County, IL     2006      57
#                     2007      71
#                     2008      68
#                     2009      69
#                     2010      71
#                     2011      44
#                     2012     104
#                     2013     427
#                     2014     442
#                     2015     488
#                     2016     737
#                     2017     936
# Genesee County, MI  2008      66
#                     2009      65
#                     2010      94
#                     2011      90
#                     2012      69
#                     2013      45
#                     2014      38
#                     2015      35
#                     2016     105
#                     2017     109
# Lake County, IN     2008      11
#                     2009      11
#                     2012      16
#                     2013      29
# ...
